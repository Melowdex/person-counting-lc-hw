# %% [markdown]
# ## Train the mobilentv3 model
# In this notebook, the mobilenetv3 model will be trained. The model will first be converted to get a single output value (count). This will be done by adding 2 dense layers at the end as done in [this research](https://www.nature.com/articles/s41598-021-02387-9). We can also compare this with an averagePooling or maxPooling at the ens to see if there are major differences.
#
# the model will be trained on three different input types:
# - 96, 96, 3
# - 128, 128, 3
# - 256, 256, 3
#
# and two different dense layers at the end:
# - 512 - 256
# - 256 - 128

# %%
import os
import sys
import time
import matplotlib.pyplot as plt
import tensorflow as tf

root_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if root_dir not in sys.path:
    sys.path.append(root_dir)

from DatasetLoader import DatasetLoader as dl
from save_info import save_model_info

# %% [markdown]
# #### 1. load the model

# %%
resoluton = [96, 128, 224]
base_models = []

for i in resoluton:
    base_models.append(tf.keras.applications.MobileNetV3Small(
        input_shape=(i, i, 3),
        alpha=1.0,
        minimalistic=True,  #even smaller model
        include_top=False,  
        weights="imagenet",
        name="MobileNetV3Small"
        ))

base_models[0].summary()
# Out:
# c:\Users\Xander Verberckt\Documents\MP-Person-counting-on-low-cost-HW\.venv\Lib\site-packages\keras\src\applications\mobilenet_v3.py:452: UserWarning: `input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
#   return MobileNetV3(
# Model: "MobileNetV3Small"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 96, 96, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_3         │ (None, 96, 96, 3) │          0 │ input_layer_3[0]… │
# │ (Rescaling)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 48, 48,    │        432 │ rescaling_3[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_bn             │ (None, 48, 48,    │         64 │ conv[0][0]        │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_69 (ReLU)     │ (None, 48, 48,    │          0 │ conv_bn[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 49, 49,    │          0 │ re_lu_69[0][0]    │
# │ (ZeroPadding2D)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 24, 24,    │        144 │ expanded_conv_de… │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 24, 24,    │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_70 (ReLU)     │ (None, 24, 24,    │          0 │ expanded_conv_de… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 24, 24,    │        256 │ re_lu_70[0][0]    │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 24, 24,    │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 24, 24,    │      1,152 │ expanded_conv_pr… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 24, 24,    │        288 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_71 (ReLU)     │ (None, 24, 24,    │          0 │ expanded_conv_1_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 25, 25,    │          0 │ re_lu_71[0][0]    │
# │ (ZeroPadding2D)     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 12, 12,    │        648 │ expanded_conv_1_… │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 12, 12,    │        288 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_72 (ReLU)     │ (None, 12, 12,    │          0 │ expanded_conv_1_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 12, 12,    │      1,728 │ re_lu_72[0][0]    │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 12, 12,    │         96 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 12, 12,    │      2,112 │ expanded_conv_1_… │
# │ (Conv2D)            │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 12, 12,    │        352 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_73 (ReLU)     │ (None, 12, 12,    │          0 │ expanded_conv_2_… │
# │                     │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 12, 12,    │        792 │ re_lu_73[0][0]    │
# │ (DepthwiseConv2D)   │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 12, 12,    │        352 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_74 (ReLU)     │ (None, 12, 12,    │          0 │ expanded_conv_2_… │
# │                     │ 88)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 12, 12,    │      2,112 │ re_lu_74[0][0]    │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 12, 12,    │         96 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_add │ (None, 12, 12,    │          0 │ expanded_conv_1_… │
# │ (Add)               │ 24)               │            │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 12, 12,    │      2,304 │ expanded_conv_2_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 12, 12,    │        384 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_75 (ReLU)     │ (None, 12, 12,    │          0 │ expanded_conv_3_… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 13, 13,    │          0 │ re_lu_75[0][0]    │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 6, 6, 96)  │        864 │ expanded_conv_3_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 6, 6, 96)  │        384 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_76 (ReLU)     │ (None, 6, 6, 96)  │          0 │ expanded_conv_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 6, 6, 40)  │      3,840 │ re_lu_76[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 6, 6, 40)  │        160 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 6, 6, 240) │      9,600 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 6, 6, 240) │        960 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_77 (ReLU)     │ (None, 6, 6, 240) │          0 │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 6, 6, 240) │      2,160 │ re_lu_77[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 6, 6, 240) │        960 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_78 (ReLU)     │ (None, 6, 6, 240) │          0 │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 6, 6, 40)  │      9,600 │ re_lu_78[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 6, 6, 40)  │        160 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_add │ (None, 6, 6, 40)  │          0 │ expanded_conv_3_… │
# │ (Add)               │                   │            │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 6, 6, 240) │      9,600 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 6, 6, 240) │        960 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_79 (ReLU)     │ (None, 6, 6, 240) │          0 │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 6, 6, 240) │      2,160 │ re_lu_79[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 6, 6, 240) │        960 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_80 (ReLU)     │ (None, 6, 6, 240) │          0 │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 6, 6, 40)  │      9,600 │ re_lu_80[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 6, 6, 40)  │        160 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_add │ (None, 6, 6, 40)  │          0 │ expanded_conv_4_… │
# │ (Add)               │                   │            │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 6, 6, 120) │      4,800 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 6, 6, 120) │        480 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_81 (ReLU)     │ (None, 6, 6, 120) │          0 │ expanded_conv_6_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 6, 6, 120) │      1,080 │ re_lu_81[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 6, 6, 120) │        480 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_82 (ReLU)     │ (None, 6, 6, 120) │          0 │ expanded_conv_6_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 6, 6, 48)  │      5,760 │ re_lu_82[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 6, 6, 48)  │        192 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 6, 6, 144) │      6,912 │ expanded_conv_6_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 6, 6, 144) │        576 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_83 (ReLU)     │ (None, 6, 6, 144) │          0 │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 6, 6, 144) │      1,296 │ re_lu_83[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 6, 6, 144) │        576 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_84 (ReLU)     │ (None, 6, 6, 144) │          0 │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 6, 6, 48)  │      6,912 │ re_lu_84[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 6, 6, 48)  │        192 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_add │ (None, 6, 6, 48)  │          0 │ expanded_conv_6_… │
# │ (Add)               │                   │            │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 6, 6, 288) │     13,824 │ expanded_conv_7_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 6, 6, 288) │      1,152 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_85 (ReLU)     │ (None, 6, 6, 288) │          0 │ expanded_conv_8_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 7, 7, 288) │          0 │ re_lu_85[0][0]    │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 3, 3, 288) │      2,592 │ expanded_conv_8_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 3, 3, 288) │      1,152 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_86 (ReLU)     │ (None, 3, 3, 288) │          0 │ expanded_conv_8_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 3, 3, 96)  │     27,648 │ re_lu_86[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 3, 3, 96)  │        384 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 3, 3, 576) │     55,296 │ expanded_conv_8_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 3, 3, 576) │      2,304 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_87 (ReLU)     │ (None, 3, 3, 576) │          0 │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 3, 3, 576) │      5,184 │ re_lu_87[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 3, 3, 576) │      2,304 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_88 (ReLU)     │ (None, 3, 3, 576) │          0 │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 3, 3, 96)  │     55,296 │ re_lu_88[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 3, 3, 96)  │        384 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_add │ (None, 3, 3, 96)  │          0 │ expanded_conv_8_… │
# │ (Add)               │                   │            │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 3, 3, 576) │     55,296 │ expanded_conv_9_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 3, 3, 576) │      2,304 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_89 (ReLU)     │ (None, 3, 3, 576) │          0 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 3, 3, 576) │      5,184 │ re_lu_89[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 3, 3, 576) │      2,304 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_90 (ReLU)     │ (None, 3, 3, 576) │          0 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 3, 3, 96)  │     55,296 │ re_lu_90[0][0]    │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 3, 3, 96)  │        384 │ expanded_conv_10… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_a… │ (None, 3, 3, 96)  │          0 │ expanded_conv_9_… │
# │ (Add)               │                   │            │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1 (Conv2D)     │ (None, 3, 3, 576) │     55,296 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1_bn           │ (None, 3, 3, 576) │      2,304 │ conv_1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_91 (ReLU)     │ (None, 3, 3, 576) │          0 │ conv_1_bn[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 441,000 (1.68 MB)
#  Trainable params: 428,888 (1.64 MB)
#  Non-trainable params: 12,112 (47.31 KB)

# %% [markdown]
# alter the models to output a count -> add dense layers

# %%
layer_name = "expanded_conv_10_add"

models = []
for i in base_models:
    model_trunc = tf.keras.models.Model(inputs=i.input, outputs=i.get_layer(layer_name).output)

    x = tf.keras.layers.Flatten()(model_trunc.output)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    x = tf.keras.layers.Dense(1)(x)

    models.append(tf.keras.models.Model(inputs=model_trunc.input, outputs=x))
    
    #save_model_info(name=f"v3_d512_256_r{i.input_shape[1]}", model=models[-1], path="model_info.yaml")

for i in base_models:
    model_trunc = tf.keras.models.Model(inputs=i.input, outputs=i.get_layer(layer_name).output)

    x = tf.keras.layers.Flatten()(model_trunc.output)
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    tf.keras.layers.Dropout(0.4)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    tf.keras.layers.Dropout(0.3)
    x = tf.keras.layers.Dense(1)(x)

    models.append(tf.keras.models.Model(inputs=model_trunc.input, outputs=x))
    
    #save_model_info(name=f"v3_d256_128_r{i.input_shape[1]}", model=models[-1], path="model_info.yaml")

# %% [markdown]
# #### 2. Load the datasets (train and validation)

# %%
datasets = []
train_ds = []

val_datasets = []
val_ds = []
counts = []
dl_loaders = []
for i in range(1, 3):
    for r in range(len(resoluton)):
        dl_loaders.append(dl("RGB", "count", resoluton[r]))

        ds, c = dl_loaders[-1].create_dataset_count("train")
        datasets.append(ds.shuffle(c, reshuffle_each_iteration=True))
        counts.append(c)

        train_ds.append((datasets[-1]
            .shuffle(c)            
            .map(lambda f, c: dl_loaders[-1].get_sample(f, c, train=True), 
                 num_parallel_calls=tf.data.AUTOTUNE)
            .batch(32)                          
            .prefetch(tf.data.AUTOTUNE)))

        ds, c = dl_loaders[-1].create_dataset_count("validate")
        val_datasets.append(ds)
        val_ds.append((val_datasets[-1]            
            .map(lambda f, c: dl_loaders[-1].get_sample(f, c, train=False), 
                 num_parallel_calls=tf.data.AUTOTUNE)
            .batch(32)                          
            .prefetch(tf.data.AUTOTUNE)))
        
model_to_ds = {
    "r96": [train_ds[0], val_ds[0]],
    "r128": [train_ds[1], val_ds[1]],
    "r224": [train_ds[2], val_ds[2]]
}

# %% [markdown]
# #### 3. Train all the models

# %%
initial_learning_rate = 0.001

for i in range(len(models)):
    models[i].compile(optimizer="Adam", loss="mae", metrics=['mae']) #tf.keras.losses.Huber(delta=1.0)

# %%
NUM_EPOCHS = 30

lr_scheduler_callback = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_mae', factor=0.5, patience=5, verbose=1,
                                                 mode='auto', min_delta=0.0005, cooldown=0, min_lr=0)
checkpoint_filepath = []
for dens in ["d512_256", "d256_128"]:
    for r in ["96", "128", "224"]:
        checkpoint_filepath.append(f"out/v3_{dens}_r{r}.keras")

for i in range(len(models)):
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath[i],
                                                                save_weights_only=False,
                                                                monitor='val_mae',
                                                                mode='min',
                                                                save_best_only=True)

    start_time = time.time()
    models[i].fit(train_ds[i],
            epochs=NUM_EPOCHS,
            validation_data=val_ds[i],
            callbacks=[lr_scheduler_callback, model_checkpoint_callback])

    print(f"Total training time = {time.time() - start_time:.2f} seconds")
# Out:
# Epoch 1/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 27s 613ms/step - loss: 11.2246 - mae: 11.2246 - val_loss: 2.8389 - val_mae: 2.8389 - learning_rate: 0.0010
# Epoch 2/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 1.6515 - mae: 1.6515 - val_loss: 3.4932 - val_mae: 3.4932 - learning_rate: 0.0010
# Epoch 3/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - loss: 1.1324 - mae: 1.1324 - val_loss: 3.1881 - val_mae: 3.1881 - learning_rate: 0.0010
# Epoch 4/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 1.1784 - mae: 1.1784 - val_loss: 3.4799 - val_mae: 3.4799 - learning_rate: 0.0010
# Epoch 5/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - loss: 1.0527 - mae: 1.0527 - val_loss: 3.7781 - val_mae: 3.7781 - learning_rate: 0.0010
# Epoch 6/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.9470 - mae: 0.9470
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.9459 - mae: 0.9459 - val_loss: 3.5311 - val_mae: 3.5311 - learning_rate: 0.0010
# Epoch 7/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - loss: 0.8647 - mae: 0.8647 - val_loss: 3.6078 - val_mae: 3.6078 - learning_rate: 5.0000e-04
# Epoch 8/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - loss: 0.7030 - mae: 0.7030 - val_loss: 3.4478 - val_mae: 3.4478 - learning_rate: 5.0000e-04
# Epoch 9/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 0.6417 - mae: 0.6417 - val_loss: 3.2599 - val_mae: 3.2599 - learning_rate: 5.0000e-04
# Epoch 10/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - loss: 0.6569 - mae: 0.6569 - val_loss: 3.1440 - val_mae: 3.1440 - learning_rate: 5.0000e-04
# Epoch 11/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.7371 - mae: 0.7371
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 0.7342 - mae: 0.7342 - val_loss: 3.3110 - val_mae: 3.3110 - learning_rate: 5.0000e-04
# Epoch 12/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - loss: 0.5320 - mae: 0.5320 - val_loss: 3.3955 - val_mae: 3.3955 - learning_rate: 2.5000e-04
# Epoch 13/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - loss: 0.5435 - mae: 0.5435 - val_loss: 3.4625 - val_mae: 3.4625 - learning_rate: 2.5000e-04
# Epoch 14/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - loss: 0.5647 - mae: 0.5647 - val_loss: 3.6089 - val_mae: 3.6089 - learning_rate: 2.5000e-04
# Epoch 15/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - loss: 0.4927 - mae: 0.4927 - val_loss: 3.8233 - val_mae: 3.8233 - learning_rate: 2.5000e-04
# Epoch 16/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.4408 - mae: 0.4408
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 266ms/step - loss: 0.4423 - mae: 0.4423 - val_loss: 3.8221 - val_mae: 3.8221 - learning_rate: 2.5000e-04
# Epoch 17/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 0.4099 - mae: 0.4099 - val_loss: 3.9215 - val_mae: 3.9215 - learning_rate: 1.2500e-04
# Epoch 18/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - loss: 0.4204 - mae: 0.4204 - val_loss: 3.9305 - val_mae: 3.9305 - learning_rate: 1.2500e-04
# Epoch 19/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.4508 - mae: 0.4508 - val_loss: 3.8967 - val_mae: 3.8967 - learning_rate: 1.2500e-04
# Epoch 20/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - loss: 0.4049 - mae: 0.4049 - val_loss: 3.8170 - val_mae: 3.8170 - learning_rate: 1.2500e-04
# Epoch 21/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.4156 - mae: 0.4156
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - loss: 0.4149 - mae: 0.4149 - val_loss: 3.8046 - val_mae: 3.8046 - learning_rate: 1.2500e-04
# Epoch 22/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - loss: 0.3795 - mae: 0.3795 - val_loss: 3.5785 - val_mae: 3.5785 - learning_rate: 6.2500e-05
# Epoch 23/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - loss: 0.3181 - mae: 0.3181 - val_loss: 3.4701 - val_mae: 3.4701 - learning_rate: 6.2500e-05
# Epoch 24/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - loss: 0.3489 - mae: 0.3489 - val_loss: 3.4453 - val_mae: 3.4453 - learning_rate: 6.2500e-05
# Epoch 25/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - loss: 0.3039 - mae: 0.3039 - val_loss: 3.4767 - val_mae: 3.4767 - learning_rate: 6.2500e-05
# Epoch 26/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.3383 - mae: 0.3383
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - loss: 0.3387 - mae: 0.3387 - val_loss: 3.3752 - val_mae: 3.3752 - learning_rate: 6.2500e-05
# Epoch 27/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - loss: 0.2929 - mae: 0.2929 - val_loss: 3.3754 - val_mae: 3.3754 - learning_rate: 3.1250e-05
# Epoch 28/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - loss: 0.3290 - mae: 0.3290 - val_loss: 3.3581 - val_mae: 3.3581 - learning_rate: 3.1250e-05
# Epoch 29/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - loss: 0.2919 - mae: 0.2919 - val_loss: 3.3623 - val_mae: 3.3623 - learning_rate: 3.1250e-05
# Epoch 30/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - loss: 0.3067 - mae: 0.3067 - val_loss: 3.4084 - val_mae: 3.4084 - learning_rate: 3.1250e-05
# Total training time = 104.14 seconds
# Epoch 1/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 271ms/step - loss: 14.7677 - mae: 14.7677 - val_loss: 7.0555 - val_mae: 7.0555 - learning_rate: 0.0010
# Epoch 2/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 217ms/step - loss: 1.8435 - mae: 1.8435 - val_loss: 5.6905 - val_mae: 5.6905 - learning_rate: 0.0010
# Epoch 3/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - loss: 1.4350 - mae: 1.4350 - val_loss: 5.9726 - val_mae: 5.9726 - learning_rate: 0.0010
# Epoch 4/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 217ms/step - loss: 1.0965 - mae: 1.0965 - val_loss: 5.2461 - val_mae: 5.2461 - learning_rate: 0.0010
# Epoch 5/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 217ms/step - loss: 1.0617 - mae: 1.0617 - val_loss: 4.3615 - val_mae: 4.3615 - learning_rate: 0.0010
# Epoch 6/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - loss: 1.0270 - mae: 1.0270 - val_loss: 6.9290 - val_mae: 6.9290 - learning_rate: 0.0010
# Epoch 7/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step - loss: 0.9188 - mae: 0.9188 - val_loss: 3.3114 - val_mae: 3.3114 - learning_rate: 0.0010
# Epoch 8/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - loss: 0.9110 - mae: 0.9110 - val_loss: 5.7216 - val_mae: 5.7216 - learning_rate: 0.0010
# Epoch 9/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - loss: 0.7079 - mae: 0.7079 - val_loss: 4.8078 - val_mae: 4.8078 - learning_rate: 0.0010
# Epoch 10/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - loss: 0.7157 - mae: 0.7157 - val_loss: 3.8651 - val_mae: 3.8651 - learning_rate: 0.0010
# Epoch 11/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - loss: 0.9074 - mae: 0.9074 - val_loss: 3.5597 - val_mae: 3.5597 - learning_rate: 0.0010
# Epoch 12/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 1.0068 - mae: 1.0068
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 202ms/step - loss: 0.9979 - mae: 0.9979 - val_loss: 3.9339 - val_mae: 3.9339 - learning_rate: 0.0010
# Epoch 13/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - loss: 0.6751 - mae: 0.6751 - val_loss: 4.4273 - val_mae: 4.4273 - learning_rate: 5.0000e-04
# Epoch 14/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 0.5690 - mae: 0.5690 - val_loss: 4.2247 - val_mae: 4.2247 - learning_rate: 5.0000e-04
# Epoch 15/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - loss: 0.4840 - mae: 0.4840 - val_loss: 4.0852 - val_mae: 4.0852 - learning_rate: 5.0000e-04
# Epoch 16/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - loss: 0.5725 - mae: 0.5725 - val_loss: 4.1223 - val_mae: 4.1223 - learning_rate: 5.0000e-04
# Epoch 17/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.5654 - mae: 0.5654
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 201ms/step - loss: 0.5644 - mae: 0.5644 - val_loss: 4.0338 - val_mae: 4.0338 - learning_rate: 5.0000e-04
# Epoch 18/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - loss: 0.4367 - mae: 0.4367 - val_loss: 4.0514 - val_mae: 4.0514 - learning_rate: 2.5000e-04
# Epoch 19/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - loss: 0.4373 - mae: 0.4373 - val_loss: 3.5172 - val_mae: 3.5172 - learning_rate: 2.5000e-04
# Epoch 20/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - loss: 0.4436 - mae: 0.4436 - val_loss: 3.5165 - val_mae: 3.5165 - learning_rate: 2.5000e-04
# Epoch 21/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - loss: 0.3812 - mae: 0.3812 - val_loss: 3.4968 - val_mae: 3.4968 - learning_rate: 2.5000e-04
# Epoch 22/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.3474 - mae: 0.3474
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - loss: 0.3488 - mae: 0.3488 - val_loss: 3.5753 - val_mae: 3.5753 - learning_rate: 2.5000e-04
# Epoch 23/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 0.3422 - mae: 0.3422 - val_loss: 3.4216 - val_mae: 3.4216 - learning_rate: 1.2500e-04
# Epoch 24/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 217ms/step - loss: 0.3146 - mae: 0.3146 - val_loss: 3.1926 - val_mae: 3.1926 - learning_rate: 1.2500e-04
# Epoch 25/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - loss: 0.2983 - mae: 0.2983 - val_loss: 3.1625 - val_mae: 3.1625 - learning_rate: 1.2500e-04
# Epoch 26/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - loss: 0.3171 - mae: 0.3171 - val_loss: 3.0915 - val_mae: 3.0915 - learning_rate: 1.2500e-04
# Epoch 27/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 223ms/step - loss: 0.2987 - mae: 0.2987 - val_loss: 2.9690 - val_mae: 2.9690 - learning_rate: 1.2500e-04
# Epoch 28/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - loss: 0.2745 - mae: 0.2745 - val_loss: 2.8680 - val_mae: 2.8680 - learning_rate: 1.2500e-04
# Epoch 29/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 220ms/step - loss: 0.2622 - mae: 0.2622 - val_loss: 2.8269 - val_mae: 2.8269 - learning_rate: 1.2500e-04
# Epoch 30/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 215ms/step - loss: 0.3014 - mae: 0.3014 - val_loss: 2.8191 - val_mae: 2.8191 - learning_rate: 1.2500e-04
# Total training time = 129.12 seconds
# Epoch 1/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 25s 672ms/step - loss: 31.0558 - mae: 31.0558 - val_loss: 3.9376 - val_mae: 3.9376 - learning_rate: 0.0010
# Epoch 2/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 537ms/step - loss: 2.1530 - mae: 2.1530 - val_loss: 8.1127 - val_mae: 8.1127 - learning_rate: 0.0010
# Epoch 3/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 538ms/step - loss: 1.7630 - mae: 1.7630 - val_loss: 9.3845 - val_mae: 9.3845 - learning_rate: 0.0010
# Epoch 4/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 540ms/step - loss: 1.4437 - mae: 1.4437 - val_loss: 7.0064 - val_mae: 7.0064 - learning_rate: 0.0010
# Epoch 5/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 552ms/step - loss: 1.1801 - mae: 1.1801 - val_loss: 6.8628 - val_mae: 6.8628 - learning_rate: 0.0010
# Epoch 6/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - loss: 1.3816 - mae: 1.3816
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 534ms/step - loss: 1.3764 - mae: 1.3764 - val_loss: 8.1293 - val_mae: 8.1293 - learning_rate: 0.0010
# Epoch 7/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 541ms/step - loss: 0.8866 - mae: 0.8866 - val_loss: 7.6628 - val_mae: 7.6628 - learning_rate: 5.0000e-04
# Epoch 8/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 560ms/step - loss: 0.7564 - mae: 0.7564 - val_loss: 8.3607 - val_mae: 8.3607 - learning_rate: 5.0000e-04
# Epoch 9/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 620ms/step - loss: 0.6841 - mae: 0.6841 - val_loss: 10.4375 - val_mae: 10.4375 - learning_rate: 5.0000e-04
# Epoch 10/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 682ms/step - loss: 0.6683 - mae: 0.6683 - val_loss: 10.6155 - val_mae: 10.6155 - learning_rate: 5.0000e-04
# Epoch 11/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - loss: 0.7058 - mae: 0.7058
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 637ms/step - loss: 0.7054 - mae: 0.7054 - val_loss: 10.2976 - val_mae: 10.2976 - learning_rate: 5.0000e-04
# Epoch 12/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 642ms/step - loss: 0.6053 - mae: 0.6053 - val_loss: 10.3792 - val_mae: 10.3792 - learning_rate: 2.5000e-04
# Epoch 13/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 646ms/step - loss: 0.5315 - mae: 0.5315 - val_loss: 11.5285 - val_mae: 11.5285 - learning_rate: 2.5000e-04
# Epoch 14/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 641ms/step - loss: 0.4825 - mae: 0.4825 - val_loss: 10.8940 - val_mae: 10.8940 - learning_rate: 2.5000e-04
# Epoch 15/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 637ms/step - loss: 0.4665 - mae: 0.4665 - val_loss: 10.1853 - val_mae: 10.1853 - learning_rate: 2.5000e-04
# Epoch 16/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - loss: 0.4430 - mae: 0.4430
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 644ms/step - loss: 0.4423 - mae: 0.4423 - val_loss: 9.6193 - val_mae: 9.6193 - learning_rate: 2.5000e-04
# Epoch 17/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 633ms/step - loss: 0.4530 - mae: 0.4530 - val_loss: 8.9066 - val_mae: 8.9066 - learning_rate: 1.2500e-04
# Epoch 18/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 631ms/step - loss: 0.3568 - mae: 0.3568 - val_loss: 8.2162 - val_mae: 8.2162 - learning_rate: 1.2500e-04
# Epoch 19/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 632ms/step - loss: 0.3610 - mae: 0.3610 - val_loss: 7.8247 - val_mae: 7.8247 - learning_rate: 1.2500e-04
# Epoch 20/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 640ms/step - loss: 0.3641 - mae: 0.3641 - val_loss: 7.2326 - val_mae: 7.2326 - learning_rate: 1.2500e-04
# Epoch 21/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 603ms/step - loss: 0.3396 - mae: 0.3396
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 642ms/step - loss: 0.3396 - mae: 0.3396 - val_loss: 5.4127 - val_mae: 5.4127 - learning_rate: 1.2500e-04
# Epoch 22/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 634ms/step - loss: 0.3085 - mae: 0.3085 - val_loss: 4.8018 - val_mae: 4.8018 - learning_rate: 6.2500e-05
# Epoch 23/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 20s 627ms/step - loss: 0.3073 - mae: 0.3073 - val_loss: 4.1734 - val_mae: 4.1734 - learning_rate: 6.2500e-05
# Epoch 24/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 633ms/step - loss: 0.2872 - mae: 0.2872 - val_loss: 3.9707 - val_mae: 3.9707 - learning_rate: 6.2500e-05
# Epoch 25/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 656ms/step - loss: 0.3023 - mae: 0.3023 - val_loss: 3.7861 - val_mae: 3.7861 - learning_rate: 6.2500e-05
# Epoch 26/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 626ms/step - loss: 0.2832 - mae: 0.2832 - val_loss: 3.9249 - val_mae: 3.9249 - learning_rate: 6.2500e-05
# Epoch 27/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 627ms/step - loss: 0.2728 - mae: 0.2728 - val_loss: 3.8355 - val_mae: 3.8355 - learning_rate: 6.2500e-05
# Epoch 28/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 13s 758ms/step - loss: 0.2750 - mae: 0.2750 - val_loss: 3.8418 - val_mae: 3.8418 - learning_rate: 6.2500e-05
# Epoch 29/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 665ms/step - loss: 0.2781 - mae: 0.2781 - val_loss: 3.7812 - val_mae: 3.7812 - learning_rate: 6.2500e-05
# Epoch 30/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 630ms/step - loss: 0.2728 - mae: 0.2728 - val_loss: 3.9224 - val_mae: 3.9224 - learning_rate: 6.2500e-05
# Total training time = 347.91 seconds
# Epoch 1/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 245ms/step - loss: 7.5614 - mae: 7.5614 - val_loss: 4.3491 - val_mae: 4.3491 - learning_rate: 0.0010
# Epoch 2/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - loss: 1.4928 - mae: 1.4928 - val_loss: 3.6234 - val_mae: 3.6234 - learning_rate: 0.0010
# Epoch 3/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - loss: 1.1389 - mae: 1.1389 - val_loss: 3.6752 - val_mae: 3.6752 - learning_rate: 0.0010
# Epoch 4/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - loss: 1.0809 - mae: 1.0809 - val_loss: 3.7854 - val_mae: 3.7854 - learning_rate: 0.0010
# Epoch 5/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 1.0077 - mae: 1.0077 - val_loss: 2.9616 - val_mae: 2.9616 - learning_rate: 0.0010
# Epoch 6/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - loss: 0.8170 - mae: 0.8170 - val_loss: 3.4864 - val_mae: 3.4864 - learning_rate: 0.0010
# Epoch 7/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 0.8473 - mae: 0.8473 - val_loss: 2.8667 - val_mae: 2.8667 - learning_rate: 0.0010
# Epoch 8/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 0.8039 - mae: 0.8039 - val_loss: 2.8832 - val_mae: 2.8832 - learning_rate: 0.0010
# Epoch 9/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.8700 - mae: 0.8700 - val_loss: 2.7914 - val_mae: 2.7914 - learning_rate: 0.0010
# Epoch 10/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.8158 - mae: 0.8158 - val_loss: 2.8456 - val_mae: 2.8456 - learning_rate: 0.0010
# Epoch 11/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - loss: 0.8000 - mae: 0.8000 - val_loss: 2.8434 - val_mae: 2.8434 - learning_rate: 0.0010
# Epoch 12/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - loss: 0.7226 - mae: 0.7226 - val_loss: 3.4564 - val_mae: 3.4564 - learning_rate: 0.0010
# Epoch 13/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - loss: 0.7034 - mae: 0.7034 - val_loss: 4.1714 - val_mae: 4.1714 - learning_rate: 0.0010
# Epoch 14/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.6323 - mae: 0.6323
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - loss: 0.6308 - mae: 0.6308 - val_loss: 3.8582 - val_mae: 3.8582 - learning_rate: 0.0010
# Epoch 15/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - loss: 0.5029 - mae: 0.5029 - val_loss: 3.1109 - val_mae: 3.1109 - learning_rate: 5.0000e-04
# Epoch 16/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - loss: 0.6471 - mae: 0.6471 - val_loss: 3.1411 - val_mae: 3.1411 - learning_rate: 5.0000e-04
# Epoch 17/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - loss: 0.5630 - mae: 0.5630 - val_loss: 2.8879 - val_mae: 2.8879 - learning_rate: 5.0000e-04
# Epoch 18/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - loss: 0.5501 - mae: 0.5501 - val_loss: 3.1354 - val_mae: 3.1354 - learning_rate: 5.0000e-04
# Epoch 19/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.4798 - mae: 0.4798
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - loss: 0.4781 - mae: 0.4781 - val_loss: 3.1557 - val_mae: 3.1557 - learning_rate: 5.0000e-04
# Epoch 20/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - loss: 0.4386 - mae: 0.4386 - val_loss: 3.2710 - val_mae: 3.2710 - learning_rate: 2.5000e-04
# Epoch 21/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - loss: 0.3884 - mae: 0.3884 - val_loss: 3.2497 - val_mae: 3.2497 - learning_rate: 2.5000e-04
# Epoch 22/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - loss: 0.4347 - mae: 0.4347 - val_loss: 3.6082 - val_mae: 3.6082 - learning_rate: 2.5000e-04
# Epoch 23/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - loss: 0.3636 - mae: 0.3636 - val_loss: 3.5535 - val_mae: 3.5535 - learning_rate: 2.5000e-04
# Epoch 24/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.4354 - mae: 0.4354
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - loss: 0.4339 - mae: 0.4339 - val_loss: 3.2554 - val_mae: 3.2554 - learning_rate: 2.5000e-04
# Epoch 25/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.3555 - mae: 0.3555 - val_loss: 3.3815 - val_mae: 3.3815 - learning_rate: 1.2500e-04
# Epoch 26/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - loss: 0.3079 - mae: 0.3079 - val_loss: 3.6112 - val_mae: 3.6112 - learning_rate: 1.2500e-04
# Epoch 27/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - loss: 0.2812 - mae: 0.2812 - val_loss: 3.5534 - val_mae: 3.5534 - learning_rate: 1.2500e-04
# Epoch 28/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - loss: 0.2807 - mae: 0.2807 - val_loss: 3.6131 - val_mae: 3.6131 - learning_rate: 1.2500e-04
# Epoch 29/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.2799 - mae: 0.2799
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - loss: 0.2805 - mae: 0.2805 - val_loss: 3.8339 - val_mae: 3.8339 - learning_rate: 1.2500e-04
# Epoch 30/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: 0.2951 - mae: 0.2951 - val_loss: 3.6936 - val_mae: 3.6936 - learning_rate: 6.2500e-05
# Total training time = 110.19 seconds
# Epoch 1/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 22s 315ms/step - loss: 6.5341 - mae: 6.5341 - val_loss: 3.6058 - val_mae: 3.6058 - learning_rate: 0.0010
# Epoch 2/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 256ms/step - loss: 2.4238 - mae: 2.4238 - val_loss: 3.5127 - val_mae: 3.5127 - learning_rate: 0.0010
# Epoch 3/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 257ms/step - loss: 1.5991 - mae: 1.5991 - val_loss: 3.4717 - val_mae: 3.4717 - learning_rate: 0.0010
# Epoch 4/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 230ms/step - loss: 0.9715 - mae: 0.9715 - val_loss: 3.6856 - val_mae: 3.6856 - learning_rate: 0.0010
# Epoch 5/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 256ms/step - loss: 0.9567 - mae: 0.9567 - val_loss: 3.1167 - val_mae: 3.1167 - learning_rate: 0.0010
# Epoch 6/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 257ms/step - loss: 0.9031 - mae: 0.9031 - val_loss: 3.0913 - val_mae: 3.0913 - learning_rate: 0.0010
# Epoch 7/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step - loss: 1.0022 - mae: 1.0022 - val_loss: 3.3399 - val_mae: 3.3399 - learning_rate: 0.0010
# Epoch 8/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 231ms/step - loss: 0.7857 - mae: 0.7857 - val_loss: 3.4018 - val_mae: 3.4018 - learning_rate: 0.0010
# Epoch 9/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step - loss: 0.7274 - mae: 0.7274 - val_loss: 3.3034 - val_mae: 3.3034 - learning_rate: 0.0010
# Epoch 10/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 230ms/step - loss: 0.7202 - mae: 0.7202 - val_loss: 3.3086 - val_mae: 3.3086 - learning_rate: 0.0010
# Epoch 11/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 0.6575 - mae: 0.6575
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 234ms/step - loss: 0.6552 - mae: 0.6552 - val_loss: 3.4019 - val_mae: 3.4019 - learning_rate: 0.0010
# Epoch 12/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - loss: 0.5282 - mae: 0.5282 - val_loss: 3.3946 - val_mae: 3.3946 - learning_rate: 5.0000e-04
# Epoch 13/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 234ms/step - loss: 0.5302 - mae: 0.5302 - val_loss: 3.2513 - val_mae: 3.2513 - learning_rate: 5.0000e-04
# Epoch 14/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 235ms/step - loss: 0.6314 - mae: 0.6314 - val_loss: 3.1707 - val_mae: 3.1707 - learning_rate: 5.0000e-04
# Epoch 15/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 230ms/step - loss: 0.4174 - mae: 0.4174 - val_loss: 3.1310 - val_mae: 3.1310 - learning_rate: 5.0000e-04
# Epoch 16/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 0.4003 - mae: 0.4003
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 229ms/step - loss: 0.4022 - mae: 0.4022 - val_loss: 3.1927 - val_mae: 3.1927 - learning_rate: 5.0000e-04
# Epoch 17/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 236ms/step - loss: 0.5091 - mae: 0.5091 - val_loss: 3.1429 - val_mae: 3.1429 - learning_rate: 2.5000e-04
# Epoch 18/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 228ms/step - loss: 0.4521 - mae: 0.4521 - val_loss: 3.1377 - val_mae: 3.1377 - learning_rate: 2.5000e-04
# Epoch 19/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step - loss: 0.3350 - mae: 0.3350 - val_loss: 3.1903 - val_mae: 3.1903 - learning_rate: 2.5000e-04
# Epoch 20/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 229ms/step - loss: 0.2988 - mae: 0.2988 - val_loss: 3.1984 - val_mae: 3.1984 - learning_rate: 2.5000e-04
# Epoch 21/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 0.3440 - mae: 0.3440
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 237ms/step - loss: 0.3442 - mae: 0.3442 - val_loss: 3.1437 - val_mae: 3.1437 - learning_rate: 2.5000e-04
# Epoch 22/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - loss: 0.3452 - mae: 0.3452 - val_loss: 3.1035 - val_mae: 3.1035 - learning_rate: 1.2500e-04
# Epoch 23/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 239ms/step - loss: 0.3059 - mae: 0.3059 - val_loss: 3.1090 - val_mae: 3.1090 - learning_rate: 1.2500e-04
# Epoch 24/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 228ms/step - loss: 0.3040 - mae: 0.3040 - val_loss: 3.1238 - val_mae: 3.1238 - learning_rate: 1.2500e-04
# Epoch 25/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 254ms/step - loss: 0.2620 - mae: 0.2620 - val_loss: 3.1140 - val_mae: 3.1140 - learning_rate: 1.2500e-04
# Epoch 26/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 0.2916 - mae: 0.2916
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 245ms/step - loss: 0.2925 - mae: 0.2925 - val_loss: 3.1016 - val_mae: 3.1016 - learning_rate: 1.2500e-04
# Epoch 27/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - loss: 0.2799 - mae: 0.2799 - val_loss: 3.0978 - val_mae: 3.0978 - learning_rate: 6.2500e-05
# Epoch 28/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 256ms/step - loss: 0.2602 - mae: 0.2602 - val_loss: 3.0909 - val_mae: 3.0909 - learning_rate: 6.2500e-05
# Epoch 29/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 230ms/step - loss: 0.2763 - mae: 0.2763 - val_loss: 3.0910 - val_mae: 3.0910 - learning_rate: 6.2500e-05
# Epoch 30/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 249ms/step - loss: 0.2353 - mae: 0.2353 - val_loss: 3.0884 - val_mae: 3.0884 - learning_rate: 6.2500e-05
# Total training time = 145.24 seconds
# Epoch 1/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 30s 713ms/step - loss: 18.9344 - mae: 18.9344 - val_loss: 3.2446 - val_mae: 3.2446 - learning_rate: 0.0010
# Epoch 2/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 626ms/step - loss: 2.9710 - mae: 2.9710 - val_loss: 3.4003 - val_mae: 3.4003 - learning_rate: 0.0010
# Epoch 3/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 634ms/step - loss: 1.5742 - mae: 1.5742 - val_loss: 4.0662 - val_mae: 4.0662 - learning_rate: 0.0010
# Epoch 4/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 656ms/step - loss: 1.3608 - mae: 1.3608 - val_loss: 2.9932 - val_mae: 2.9932 - learning_rate: 0.0010
# Epoch 5/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 626ms/step - loss: 1.2424 - mae: 1.2424 - val_loss: 3.2059 - val_mae: 3.2059 - learning_rate: 0.0010
# Epoch 6/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 654ms/step - loss: 1.0449 - mae: 1.0449 - val_loss: 2.9542 - val_mae: 2.9542 - learning_rate: 0.0010
# Epoch 7/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 627ms/step - loss: 0.9598 - mae: 0.9598 - val_loss: 2.9878 - val_mae: 2.9878 - learning_rate: 0.0010
# Epoch 8/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 631ms/step - loss: 0.9088 - mae: 0.9088 - val_loss: 2.9971 - val_mae: 2.9971 - learning_rate: 0.0010
# Epoch 9/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 631ms/step - loss: 0.8624 - mae: 0.8624 - val_loss: 3.2159 - val_mae: 3.2159 - learning_rate: 0.0010
# Epoch 10/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 646ms/step - loss: 0.7673 - mae: 0.7673 - val_loss: 2.8284 - val_mae: 2.8284 - learning_rate: 0.0010
# Epoch 11/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 623ms/step - loss: 1.0047 - mae: 1.0047 - val_loss: 2.8327 - val_mae: 2.8327 - learning_rate: 0.0010
# Epoch 12/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 622ms/step - loss: 0.7364 - mae: 0.7364 - val_loss: 2.9346 - val_mae: 2.9346 - learning_rate: 0.0010
# Epoch 13/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 21s 619ms/step - loss: 0.7389 - mae: 0.7389 - val_loss: 2.9013 - val_mae: 2.9013 - learning_rate: 0.0010
# Epoch 14/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 656ms/step - loss: 0.8456 - mae: 0.8456 - val_loss: 2.7766 - val_mae: 2.7766 - learning_rate: 0.0010
# Epoch 15/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 644ms/step - loss: 0.6189 - mae: 0.6189 - val_loss: 2.8896 - val_mae: 2.8896 - learning_rate: 0.0010
# Epoch 16/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 622ms/step - loss: 0.6045 - mae: 0.6045 - val_loss: 3.8378 - val_mae: 3.8378 - learning_rate: 0.0010
# Epoch 17/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 628ms/step - loss: 0.7431 - mae: 0.7431 - val_loss: 2.8678 - val_mae: 2.8678 - learning_rate: 0.0010
# Epoch 18/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 624ms/step - loss: 0.8846 - mae: 0.8846 - val_loss: 2.8537 - val_mae: 2.8537 - learning_rate: 0.0010
# Epoch 19/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - loss: 0.7386 - mae: 0.7386
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 628ms/step - loss: 0.7383 - mae: 0.7383 - val_loss: 2.8732 - val_mae: 2.8732 - learning_rate: 0.0010
# Epoch 20/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 629ms/step - loss: 0.6431 - mae: 0.6431 - val_loss: 2.9897 - val_mae: 2.9897 - learning_rate: 5.0000e-04
# Epoch 21/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 625ms/step - loss: 0.5104 - mae: 0.5104 - val_loss: 2.8038 - val_mae: 2.8038 - learning_rate: 5.0000e-04
# Epoch 22/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 621ms/step - loss: 0.5174 - mae: 0.5174 - val_loss: 3.0136 - val_mae: 3.0136 - learning_rate: 5.0000e-04
# Epoch 23/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 628ms/step - loss: 0.4255 - mae: 0.4255 - val_loss: 2.9882 - val_mae: 2.9882 - learning_rate: 5.0000e-04
# Epoch 24/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 587ms/step - loss: 0.4721 - mae: 0.4721
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 628ms/step - loss: 0.4711 - mae: 0.4711 - val_loss: 2.8008 - val_mae: 2.8008 - learning_rate: 5.0000e-04
# Epoch 25/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 626ms/step - loss: 0.3499 - mae: 0.3499 - val_loss: 2.8400 - val_mae: 2.8400 - learning_rate: 2.5000e-04
# Epoch 26/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 623ms/step - loss: 0.3174 - mae: 0.3174 - val_loss: 2.8999 - val_mae: 2.8999 - learning_rate: 2.5000e-04
# Epoch 27/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 636ms/step - loss: 0.3381 - mae: 0.3381 - val_loss: 3.1937 - val_mae: 3.1937 - learning_rate: 2.5000e-04
# Epoch 28/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 623ms/step - loss: 0.2577 - mae: 0.2577 - val_loss: 2.8696 - val_mae: 2.8696 - learning_rate: 2.5000e-04
# Epoch 29/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - loss: 0.2947 - mae: 0.2947
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 11s 660ms/step - loss: 0.2960 - mae: 0.2960 - val_loss: 2.8328 - val_mae: 2.8328 - learning_rate: 2.5000e-04
# Epoch 30/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 683ms/step - loss: 0.3392 - mae: 0.3392 - val_loss: 2.7722 - val_mae: 2.7722 - learning_rate: 1.2500e-04
# Total training time = 357.24 seconds

# %%
import yaml
import re

RES_FILE = "results.yaml"

def write_res(file_path, name, new_metrics):

    if os.path.exists(file_path) and os.path.getsize(file_path) > 0:
        with open(file_path, 'r') as file:
            existing_data = yaml.safe_load(file) or {}
    else:
        existing_data = {}

    existing_data[name] = new_metrics

    with open(file_path, 'w') as file:
        yaml.dump(existing_data, file, sort_keys=False)

for i in checkpoint_filepath:
    res = int(re.search(r"r(\d+)", i).group(1))
    name = i
    saved_model = tf.keras.models.load_model(name, compile=True)

    loss = saved_model.evaluate(model_to_ds[f"r{str(res)}"][1])
    write_res(RES_FILE, name.replace(".keras", ""), {"loss": loss, "params": saved_model.count_params()})
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 1.8485 - mae: 1.8485
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 1.8208 - mae: 1.8208
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - loss: 4.4591 - mae: 4.4591
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 1.8523 - mae: 1.8523
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 2.5319 - mae: 2.5319
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 1.7685 - mae: 1.7685

# %%
for i in range(len(models)):
    save_model_info(checkpoint_filepath[i].replace("out/", "").replace(".keras", ""), models[i], "model_info.yaml")
# Out:
# Model info saved to model_info.yaml
# Model info saved to model_info.yaml
# Model info saved to model_info.yaml
# Model info saved to model_info.yaml
# Model info saved to model_info.yaml
# Model info saved to model_info.yaml
